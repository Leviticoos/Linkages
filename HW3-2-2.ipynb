# %%
#%matplotlib notebook
# this command tells notebook to display plots in the notebook
from math import *
from sympy import *
import numpy as np

from graphics import *
import matplotlib.pyplot as plt

#graphics screen window and screen coordinates
win = GraphWin("Linkages",1500,900)
win.setCoords(-10,-15,25,8)

#set up all the variables and vectors
#Set up unknowns, 
t0, t1, t4, t5, t6 = symbols("t0 t1 t4 t5 t6", real=True)
unkown = (t0, t1, t5, t6)
input = t4
#setup ground points
g = []
g.append(0*exp(I*0))
g.append(5.6*exp(I*radians(65)))
g.append(6.6*exp(I*radians(66)))
#set up linkage equations
r = []
r0 = 6.6*exp(I*t0)
r1 = 1.4*exp(I*t1)
r2 = 3.9*exp(I*(t1-radians(90)))
r4 = 1.6*exp(I*t4)
r5 = 3.7*exp(I*t5)
r6 = 4.1*exp(I*t6)
r7 = 3*exp(I*(t5+radians(107)))

#set up static Graphics (Ground, special areas etc.)
gPt = []
for i in g:
    gPt.append(Point(re(i),im(i)))

#create graphics points for the ground pivots
#goA = Point(0,0)
#goB = Point(re(r1),im(r1))

#write out the equations for linkage (looks just like what we put on the board)
eq1 = g[2] - (r0 + r1 + r2 + r5 + r6)
eq2 = g[1] - (r1 + r2 + r4)

#Initial Guess
#This guess should be good for the starting angles. Then the solved angles will be used to seed next loop
guess = (radians(91), radians(44), radians(46), radians(180+135))

# loop through input angle from 0 -> 360 by 5 degrees (can't go finer than 1 degree or you must change arrays)
run = True
#i is start angle, step is degrees change every time
i = -91
step = 1
while run == True:
    # compute loop eq with t2 substituted 
    eq1_slv = eq1.subs(t4,radians(i))
    eq2_slv = eq2.subs(t4,radians(i))
    #print("eq2=",eq2)
    ans = nsolve((re(eq1_slv),im(eq1_slv),re(eq2_slv),im(eq2_slv)), (t0,t1,t5,t6), guess, verify=False)
    
    #print(eq1_slv.evalf(subs = { tuple(unkown):tuple(ans) }))
    for j in range(0,len(ans),1):
        print(unkown[j], ans[j])
        eq1_slv = eq1_slv.subs(unkown[j],ans[j])
    if abs(im(eq1_slv)) > 0.00001:
        step = -1 * step

    guess = ans
    t2_ans, t5_ans, t6_ans, t7_ans = ans

    #substitute solutions into r-vectors to get numerical values
    v = []
    v.append(r1.subs(t1, radians(i)))
    v.append(r2.subs(t2, t2_ans))
    v.append(r3.subs(t2, t2_ans))
    v.append(r4.subs(t2, t2_ans))
    v.append(r5.subs(t5,t5_ans))
    v.append(r6.subs(t6, t6_ans))
    v.append(r7.subs(t7, t7_ans))

    
    #create graphics points for mechanism points A, B & C.
    gptA = Point(re(v[0]),im(v[0]))
    gptB = Point(re(v[0] + v[1]),im(v[0] + v[1]))
    gptC = Point(re(v[0] + v[1] + v[4]),im(v[0] + v[1] + v[4]))
    gptD = Point(re(v[0] + v[2]), im(v[0] + v[2]))
    gptI = Point(re(v[0] + v[3]), im(v[0] + v[3]))


    #Levi Inserted window clear
    for item in win.items[:]:
        if str(type(item)) == "<class 'graphics.Line'>":
            item.undraw()
    win.update()

    #create graphic lines and draw them.
    # line = Line(goA,gptA)
    # line.draw(win)
    Line(gPt[0],gptA).draw(win).setOutline('red')
    Line(gptA,gptB).draw(win)
    Line(gptB,gptC).draw(win)
    Line(gptC,gPt[1]).draw(win)
    Line(gptA, gptD).draw(win)
    Line(gptD,gPt[2]).draw(win)
    Line(gptA,gptI).draw(win)

    if i <= 360:
        gptI.draw(win)

    i += step

#graphics
win.getMouse() #this waits until user clicks mouse
win.close()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 61
#      59 eq2_slv = eq2.subs(t4,radians(i))
#      60 #print("eq2=",eq2)
# ---> 61 ans = nsolve((re(eq1_slv),im(eq1_slv),re(eq2_slv),im(eq2_slv)), (t0,t1,t5,t6), guess, verify=False)
#      63 #print(eq1_slv.evalf(subs = { tuple(unkown):tuple(ans) }))
#      64 for j in range(0,len(ans),1):
#
# File c:\Users\Levi Rhoden\anaconda3\lib\site-packages\sympy\utilities\decorator.py:88, in conserve_mpmath_dps.<locals>.func_wrapper(*args, **kwargs)
#      86 dps = mpmath.mp.dps
#      87 try:
# ---> 88     return func(*args, **kwargs)
#      89 finally:
#      90     mpmath.mp.dps = dps
#
# File c:\Users\Levi Rhoden\anaconda3\lib\site-packages\sympy\solvers\solvers.py:2961, in nsolve(dict, *args, **kwargs)
#    2959 J = lambdify(fargs, J, modules)
#    2960 # solve the system numerically
# -> 2961 x = findroot(f, x0, J=J, **kwargs)
#    2962 if as_dict:
#    2963     return [dict(zip(fargs, [sympify(xi) for xi in x]))]
#
# File c:\Users\Levi Rhoden\anaconda3\lib\site-packages\mpmath\calculus\optimization.py:969, in findroot(ctx, f, x0, solver, tol, verbose, verify, **kwargs)
#     967     maxsteps = iterations.maxsteps
#     968 i = 0
# --> 969 for x, error in iterations:
#     970     if verbose:
#     971         print('x:    ', x)
#
# File c:\Users\Levi Rhoden\anaconda3\lib\site-packages\mpmath\calculus\optimization.py:660, in MDNewton.__iter__(self)
#     658 fxn = -fx
#     659 Jx = J(*x0)
# --> 660 s = self.ctx.lu_solve(Jx, fxn)
#     661 if self.verbose:
#     662     print('Jx:')
#
# File c:\Users\Levi Rhoden\anaconda3\lib\site-packages\mpmath\matrices\linalg.py:226, in LinearAlgebraMethods.lu_solve(ctx, A, b, **kwargs)
#     223         x = ctx.lu_solve(A, b)
#     224 else:
#     225     # LU factorization
# --> 226     A, p = ctx.LU_decomp(A)
#     227     b = ctx.L_solve(A, b, p)
#     228     x = ctx.U_solve(A, b)
#
# File c:\Users\Levi Rhoden\anaconda3\lib\site-packages\mpmath\matrices\linalg.py:136, in LinearAlgebraMethods.LU_decomp(ctx, A, overwrite, use_cache)
#     134 s = ctx.fsum([ctx.absmin(A[k,l]) for l in xrange(j, n)])
#     135 if ctx.absmin(s) <= tol:
# --> 136     raise ZeroDivisionError('matrix is numerically singular')
#     137 current = 1/s * ctx.absmin(A[k,j])
#     138 if current > biggest: # TODO: what if equal?
#
# ZeroDivisionError: matrix is numerically singular
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
