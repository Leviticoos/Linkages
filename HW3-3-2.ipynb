# %%
#%matplotlib notebook
# this command tells notebook to display plots in the notebook
from math import *
from sympy import *
import numpy as np

from graphics import *
import matplotlib.pyplot as plt

#graphics screen window and screen coordinates
win = GraphWin("Linkages",1500,900)
win.setCoords(-10,-15,25,8)

#set up all the variables and vectors
#Set up unknowns, 
t0, t1, t2 = symbols("t0 t1 t2", real=True)
unkown = [t1, t2]
input = t0
#setup ground points
g = []
g.append(0*exp(I*0))
g.append(2.5*exp(I*radians(180)))
#set up linkage equations
r = []
r0 = 4*exp(I*t0)
r1 = 3.5*exp(I*t1)
r2 = 5*exp(I*t2)


#set up static Graphics (Ground, special areas etc.)
gPt = []
for i in g:
    gPt.append(Point(re(i),im(i)))

#create graphics points for the ground pivots
#goA = Point(0,0)
#goB = Point(re(r1),im(r1))

#write out the equations for linkage (looks just like what we put on the board)
eq1 = g[1] - (r0 + r1 + r2)

#Initial Guess
#This guess should be good for the starting angles. Then the solved angles will be used to seed next loop
guess = (radians(180), radians(180+135))

# loop through input angle from 0 -> 360 by 5 degrees (can't go finer than 1 degree or you must change arrays)
run = True
#i is start angle, step is degrees change every time
i = 150
step = -2
while run == True:
    # compute loop eq with t2 substituted 
    eq1_slv = eq1.subs(t0,radians(i))
    #print("eq2=",eq2)
    ans = nsolve((re(eq1_slv),im(eq1_slv)), (t1, t2), guess, verify=False)
    
    #print(eq1_slv.evalf(subs = { tuple(unkown):tuple(ans) }))
    for j in range(0,len(ans),1):
        print(unkown[j], ans[j])
        eq1_slv = eq1_slv.subs(unkown[j],ans[j])
    if abs(im(eq1_slv)) > 0.00001:
        step = -1 * step

    guess = ans
    t1_ans, t2_ans = ans

    #substitute solutions into r-vectors to get numerical values
    v = []
    v.append(r0.subs(t0, radians(i)))
    v.append(r1.subs(t1, t1_ans))
    v.append(r2.subs(t2, t2_ans))

    
    #create graphics points for mechanism points A, B & C.
    gptA = Point(re(v[0]),im(v[0]))
    gptB = Point(re(v[0] + v[1]),im(v[0] + v[1]))
    gptC = Point(re(v[0] + v[1] + v[2]),im(v[0] + v[1] + v[2]))


    #Levi Inserted window clear
    for item in win.items[:]:
        if str(type(item)) == "<class 'graphics.Line'>":
            item.undraw()
    win.update()

    #create graphic lines and draw them.
    # line = Line(goA,gptA)
    # line.draw(win)
    Line(gPt[0],gptA).draw(win).setOutline('red')
    Line(gptA,gptB).draw(win)
    Line(gptB,gptC).draw(win)
    Line(gptC,gPt[1]).draw(win)

    if i <= 360:
        gptA.draw(win)

    i += step

#graphics
win.getMouse() #this waits until user clicks mouse
win.close()
# Out:
# t1 3.06348671374319
# t2 5.81124136637960
# t1 3.05810228442151
# t2 5.77989461051622
# t1 3.05268270880913
# t2 5.74857086347662
# t1 3.04722553103066
# t2 5.71727172921840
# t1 3.04172824645731
# t2 5.68599884281834
# t1 3.03618829836776
# t2 5.65475387257768
# t1 3.03060307453094
# t2 5.62353852217171
# t1 3.02496990370749
# t2 5.59235453284519
# t1 3.01928605206674
# t2 5.56120368565464
# t1 3.01354871951681
# t2 5.53008780375860
# t1 3.00775503594533
# t2 5.49900875475623
# t1 3.00190205736927
# t2 5.46796845307463
# t1 2.99598676199244
# t2 5.43696886240443
# t1 2.99000604617024
# t2 5.40601199818298
# t1 2.98395672028177
# t2 5.37509993012371
# t1 2.06419248349457
# t2 3.51984511044650
# t1 2.03832536636482
# t2 3.50051251092655
# t1 2.01200000967293
# t2 3.48137463224974
# t1 1.98521831083290
# t2 3.46242351815230
# t1 1.95798236348416
# t2 3.44365074113432
# t1 1.93029441039713
# t2 3.42504741747119
# t1 1.90215679498130
# t2 3.40660422182769
# t1 1.87357191174908
# t2 3.38831140109350
# t1 1.84454215605258
# t2 3.37015878707230
# t1 1.81506987336695
# t2 3.35213580767405
# t1 1.78515730834634
# t2 3.33423149627915
# t1 1.75480655382653
# t2 3.31643449896329
# t1 1.72401949989438
# t2 3.29873307929191
# t1 1.69279778308860
# t2 3.28111512041220
# t1 1.66114273574091
# t2 3.26356812418709
# t1 1.62905533541115
# t2 3.24607920712958
# t1 1.59653615431525
# t2 3.22863509290597
# t1 1.56358530859213
# t2 3.21122210118220
# t1 1.53020240720312
# t2 3.19382613258855
# t1 1.49638650020695
# t2 3.17643264957374
# t1 1.46213602610347
# t2 3.15902665290937
# t1 1.42744875788953
# t2 3.14159265358979
# t1 1.39232174742097
# t2 3.12411463985014
# t1 1.35675126762419
# t2 3.10657603899602
# t1 1.32073275204833
# t2 3.08895967370247
# t1 1.28426073119413
# t2 3.07124771239565
# t1 1.24732876499684
# t2 3.05342161327935
# t1 1.20992937077657
# t2 3.03546206150731
# t1 1.17205394589944
# t2 3.01734889893272
# t1 1.13369268431512
# t2 2.99906104578544
# t1 1.09483448604886
# t2 2.98057641353574
# t1 1.05546685862836
# t2 2.96187180809854
# t1 1.01557580931439
# t2 2.94292282241323
# t1 0.975145726878103
# t2 2.92370371729928
# t1 0.934159251524830
# t2 2.90418728933521
# t1 0.892597131401017
# t2 2.88434472433540
# t1 0.850438063935735
# t2 2.86414543480427
# t1 0.807658520057517
# t2 2.84355687952643
# t1 0.764232549088296
# t2 2.82254436320254
# t1 0.720131561845635
# t2 2.80107081376083
# t1 0.675324089178916
# t2 2.77909653465898
# t1 0.629775512821692
# t2 2.75657892913942
# t1 0.583447765058007
# t2 2.73347219300794
# t1 0.536298993273334
# t2 2.70972697207097
# t1 0.488283184990002
# t2 2.68528997988857
# t1 0.439349748474256
# t2 2.66010357098105
# t1 0.389443043452309
# t2 2.63410526407077
# t1 0.338501855896247
# t2 2.60722720935899
# t1 0.286458810255563
# t2 2.57939559324687
# t1 0.233239711946354
# t2 2.55052997334172
# t1 0.178762812414356
# t2 2.52054253608905
# t1 0.122937988731192
# t2 2.48933726901062
# t1 0.0656658295710211
# t2 2.45680903941296
# t1 0.00683661970214369
# t2 2.42284257171488
# t1 -0.0536707839614754
# t2 2.38731131645052
# t1 -0.115990189850368
# t2 2.35007620585499
# t1 -0.180269424624645
# t2 2.31098429418626
# t1 -0.246671798031050
# t2 2.26986728621074
# t1 -0.315377668129661
# t2 2.22653996545824
# t1 -0.386586083009858
# t2 2.18079854612784
# t1 -0.460516457132212
# t2 2.13241899050856
# t1 -0.537410214631276
# t2 2.08115535957865
# t1 -0.617532295590227
# t2 2.02673830077081
# t1 -0.701172371132229
# t2 1.96887382705551
# t1 -0.788645545339907
# t2 1.90724260932758
# t1 -0.880292232572731
# t2 1.84150009352198
# t1 -0.976476784548358
# t2 1.77127786808805
# t1 -1.07758430199249
# t2 1.69618684701241
# t1 -1.18401490582372
# t2 1.61582299341845
# t1 -1.29617457847776
# t2 1.52977647313209
# t1 -1.41446155069240
# t2 1.43764526288619
# t1 -1.53924716314592
# t2 1.33905428376449
# t1 -1.67085027063443
# t2 1.23368099219303
# t1 -1.80950470919440
# t2 1.12128790806566
# t1 -1.95532026144757
# t2 1.00176164472005
# t1 -2.10823904577023
# t2 0.875156515154611
# t1 -2.26799130174734
# t2 0.741738742019188
# t1 -2.43405686369735
# t2 0.602024979586171
# t1 -2.60564054841104
# t2 0.456806921551597
# t1 -2.78167023812171
# t2 0.307153213641688
# t1 -2.96082459546399
# t2 0.154381734260073
# t1 -3.14164413101573
# t2 -3.60341981867717e-5
# t1 -3.14672090041464
# t2 -0.0315145706905834
# t1 -3.15185122884610
# t2 -0.0630277770827077
# t1 -3.15698572313968
# t2 -0.0945382531770497
# t1 -3.16212647285334
# t2 -0.126044629569819
# t1 -3.16727557551015
# t2 -0.157545531743620
# t1 -3.17243513927489
# t2 -0.189039578350046
# t1 -3.17760728564889
# t2 -0.220525379481277
# t1 -3.18279415218800
# t2 -0.252001534927940
# t1 -3.18799789524797
# t2 -0.283466632420517
# t1 -3.19322069276206
# t2 -0.314919245851639
# t1 -3.19846474705518
# t2 -0.346357933476593
# t1 -3.20373228769927
# t2 -0.377781236089423
# t1 -3.20902557441424
# t2 -0.409187675172070
# t1 -3.21434690001892
# t2 -0.440575751014016
# t1 -3.21969859343640
# t2 -0.471943940799988
# t1 -3.22508302275807
# t2 -0.503290696663361
# t1 -3.23050259837046
# t2 -0.534614443702970
# t1 -3.23595977614893
# t2 -0.565913577961188
# t1 -3.24145706072228
# t2 -0.597186464361243
# t1 -3.24699700881183
# t2 -0.628431434601905
# t1 -3.25258223264864
# t2 -0.659646785007872
# t1 -3.25821540347210
# t2 -0.690830774334394
# t1 -3.26389925511284
# t2 -0.721981621524941
# t1 -3.26963658766278
# t2 -0.753097503420986
# t1 -3.27543027123426
# t2 -0.784176552423354
# t1 -3.28128324981032
# t2 -0.815216854104954
# t1 -3.28719854518715
# t2 -0.846216444775156
# t1 -3.29317926100935
# t2 -0.877173308996610
# t1 -3.29922858689782
# t2 -0.908085377055877
# t1 -3.30534980266933
# t2 -0.938950522389900
# t1 -3.31154628264581
# t2 -0.969766558971115
# t1 -3.31782150005020
# t2 -1.00053123865483
# t1 -3.32417903148482
# t2 -1.03124224849351
# t1 -3.33062256148631
# t2 -1.06189720802357
# t1 -3.33715588715014
# t2 -1.09249366653168
# t1 -3.34378292281546
# t2 -1.12302910030867
# t1 -3.35050770479947
# t2 -1.15350090990089
# t1 -3.35733439616802
# t2 -1.18390641737039
# t1 -3.36426729152693
# t2 -1.21424286357700
# t1 -3.37131082181557
# t2 -1.24450740549784
# t1 -3.37846955908152
# t2 -1.27469711360145
# t1 -3.38574822121178
# t2 -1.30480896929658
# t1 -3.39315167659238
# t2 -1.33483986247813
# t1 -3.40068494866454
# t2 -1.36478658919563
# t1 -3.40835322034118
# t2 -1.39464584947265
# t1 -3.41616183824331
# t2 -1.42441424530893
# t1 -3.42411631671093
# t2 -1.45408827890054
# t1 -3.43222234153804
# t2 -1.48366435111686
# t1 -3.44048577337615
# t2 -1.51313876027731
# t1 -3.44891265074492
# t2 -1.54250770127474
# t1 -3.45750919258322
# t2 -1.57176726509634
# t1 -3.46628180026779
# t2 -1.60091343879747
# t1 -3.47523705902095
# t2 -1.62994210598768
# t1 -3.48438173862338
# t2 -1.65884904789264
# t1 -3.49372279334195
# t2 -1.68762994505945
# t1 -3.50326736097807
# t2 -1.71628037977655
# t1 -3.51302276093699
# t2 -1.74479583928285
# t1 -3.52299649121509
# t2 -1.77317171984325
# t1 -3.53319622419902
# t2 -1.80140333176984
# t1 -3.54362980116938
# t2 -1.82948590546911
# t1 -3.55430522540145
# t2 -1.85741459859555
# t1 -3.56523065375738
# t2 -1.88518450439059
# t1 -3.57641438666836
# t2 -1.91279066128293
# t1 -3.58786485641184
# t2 -1.94022806382177
# t1 -3.59959061359814
# t2 -1.96749167500742
# t1 -3.61160031179363
# t2 -1.99457644007520
# t1 -3.62390269022309
# t2 -2.02147730177691
# t1 -3.63650655451397
# t2 -2.04818921719036
# t1 -3.64942075546827
# t2 -2.07470717607074
# t1 -3.66265416587514
# t2 -2.10102622073838
# t1 -3.67621565540822
# t2 -2.12714146747540
# t1 -3.69011406368641
# t2 -2.15304812937931
# t1 -3.70435817161460
# t2 -2.17874154059489
# t1 -3.71895667116135
# t2 -2.20421718181693
# t1 -3.73391813377325
# t2 -2.22947070692686
# t1 -3.74925097766916
# t2 -2.25449797059511
# t1 -3.76496343430132
# t2 -2.27929505665116
# t1 -3.78106351431267
# t2 -2.30385830699328
# t1 -3.79755897335949
# t2 -2.32818435078269
# t1 -3.81445727820418
# t2 -2.35227013364245
# t1 -3.83176557351307
# t2 -2.37611294656114
# t1 -3.84949064981690
# t2 -2.39971045418629
# t1 -3.86763891310636
# t2 -2.42306072218389
# t1 -3.88621635653961
# t2 -2.44616224333845
# t1 -3.90522853473301
# t2 -2.46901396207412
# t1 -3.92468054108929
# t2 -2.49161529709166
# t1 -3.94457698858908
# t2 -2.51396616183829
# t1 -3.96492199443222
# t2 -2.53606698255835
# t1 -3.98571916886540
# t2 -2.55791871371073
# t1 -4.00697160847370
# t2 -2.57952285058417
# t1 -4.02868189414680
# t2 -2.60088143899213
# t1 -4.05085209385825
# t2 -2.62199708198438
# t1 -4.07348377032044
# t2 -2.64287294356965
# t1 -4.09657799350075
# t2 -2.66351274950313
# t1 -4.12013535790926
# t2 -2.68392078525038
# t1 -4.14415600449638
# t2 -2.70410189129521
# t1 -4.16863964693337
# t2 -2.72406145601090
# t1 -4.19358560199120
# t2 -2.74380540636059
# t1 -4.21899282368502
# t2 -2.76334019673309
# t1 -4.24485994081477
# t2 -2.78267279625303
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# <ipython-input-1-1dc94604d37f> in <module>
#      87     # line = Line(goA,gptA)
#      88     # line.draw(win)
# ---> 89     Line(gPt[0],gptA).draw(win).setOutline('red')
#      90     Line(gptA,gptB).draw(win)
#      91     Line(gptB,gptC).draw(win)
#
# c:\VS\Linkages\graphics.py in draw(self, graphwin)
#     480
#     481         if self.canvas and not self.canvas.isClosed(): raise GraphicsError(OBJ_ALREADY_DRAWN)
# --> 482         if graphwin.isClosed(): raise GraphicsError("Can't draw to closed window")
#     483         self.canvas = graphwin
#     484         self.id = self._draw(graphwin, self.config)
#
# GraphicsError: Can't draw to closed window
